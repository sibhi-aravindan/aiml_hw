# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
url ="https://raw.githubusercontent.com/rames4498/Bootcamps_and_workshops/master/my_bank.csv"
df =pd.DataFrame(pd.read_csv(url))

# %%
df
# Out:
#         ID  Age  Experience  ...  CD Account  Online  CreditCard
# 0        1   25           1  ...           0       0           0
# 1        2  200          19  ...           0       0           0
# 2        3   39          15  ...           0       0           0
# 3        4   35           9  ...           0       0           0
# 4        5   35           8  ...           0       0           1
# ...    ...  ...         ...  ...         ...     ...         ...
# 5000  5001   56          30  ...           0       1           1
# 5001  5002   38          13  ...           1       1           1
# 5002  5003   59          35  ...           0       1           0
# 5003  5004   40          16  ...           0       1           0
# 5004  5005   53          28  ...           0       0           0
#
# [5005 rows x 14 columns]

# %%
df=df.drop('Phone',axis=1)
df

# %%
df.isnull().sum()

# %%
df["CCAvg"].mean()
df["CCAvg"].fillna(value=df["CCAvg"].mean(),inplace=True)
df

# %%
for i in df.columns:
  df[i].fillna(value=df[i].mean(),inplace=True)
df
# Out:
#         ID  Age  Experience  ...  CD Account  Online  CreditCard
# 0        1   25           1  ...           0       0           0
# 1        2  200          19  ...           0       0           0
# 2        3   39          15  ...           0       0           0
# 3        4   35           9  ...           0       0           0
# 4        5   35           8  ...           0       0           1
# ...    ...  ...         ...  ...         ...     ...         ...
# 5000  5001   56          30  ...           0       1           1
# 5001  5002   38          13  ...           1       1           1
# 5002  5003   59          35  ...           0       1           0
# 5003  5004   40          16  ...           0       1           0
# 5004  5005   53          28  ...           0       0           0
#
# [5005 rows x 14 columns]
